# %% [raw]
# ---
# description: "Epic 2 — GAN-based defect generation (Notion roadmap); placeholder hub"
# output-file: epic2-gan-overview.html
# title: "Epic 2 — GAN Overview"
# ---

# %% [markdown]
# # Epic 2 — GAN-Based Defect Generation
#
# **Notion:** Synthetic Data Generation → Epic 2 (GAN) — ControlNet / rare-class synthetic defects.
#
# **This repository** is primarily **Epic 1** (physics + pipeline). Use this notebook as the **Epic 2 anchor** when you add GAN training code, either here under `scripts/epic2/` or a sibling repo.
#
# ## Naming in this project
#
# | Pattern | Meaning |
# |---------|--------|
# | `nbs/epic1_*` | Epic 1 notebooks |
# | `nbs/epic2_*` | Epic 2 notebooks (start here) |
# | `scripts/epic2/` | Epic 2 CLI / training scripts |
#
# ## Implemented in this repo (US 2.1–2.6)
#
# - **`udm-epic2`** CLI: `extract-crops`, `export-hf`, `train`, `generate`, `paste`, `ablation-template`.
# - Install: `uv pip install -e ".[epic2]"` (diffusers / accelerate / transformers).
# - See `README.md` Epic 2 table and `configs/epic2_*.yaml`.
# - Notebooks: `epic2_01_dataset_prep.ipynb` (crops); training/generation use CLI + YAML.

# %%
# US 2.3+: from diffusers import ...  (add diffusers/accelerate when you start ControlNet fine-tuning)
print("Epic 2 — dataset prep implemented; add diffusion training imports here when ready.")
