# %% [markdown]
# # Beer-Lambert Physics
# > X-ray void synthesis using Beer-Lambert law: I = I₀ · exp(−μ · t)

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
from udm_epic1.physics.beer_lambert import BeerLambertSimulator, BeerLambertConfig

# %%
from nbdev.showdoc import show_doc
show_doc(BeerLambertSimulator.generate_background_field)
show_doc(BeerLambertSimulator.insert_void)
show_doc(BeerLambertSimulator.percentile_normalize)
